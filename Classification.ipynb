# %%
import classification
# from classification import classification
from importlib import reload
reload(classification)
# import classification
# from classification import classification

classification.classification(model_name = 'NF')
# Out:
# Названия колонок в таблице ANTARES_NEW.csv со всеми кривыми блеска:
#
#  Index(['object_id', 'mjd', 'passband', 'flux', 'flux_err', 'obj_type',
#        'peak_time'],
#       dtype='object')
#
#
# Количество объектов:  1870
# NF
# Названия колонок в таблице ANTARES_NEW.csv со всеми кривыми блеска:
#
#  Index(['object_id', 'mjd', 'passband', 'flux', 'flux_err', 'obj_type',
#        'peak_time'],
#       dtype='object')
#
#
# Количество объектов:  1870
# Названия колонок в таблице ANTARES_NEW.csv со всеми кривыми блеска:
#
#  Index(['object_id', 'mjd', 'passband', 'flux', 'flux_err', 'obj_type',
#        'peak_time'],
#       dtype='object')
#
#
# Названия колонок в таблице ANTARES_NEW.csv со всеми кривыми блеска:
#
#  Index(['object_id', 'mjd', 'passband', 'flux', 'flux_err', 'obj_type',
#        'peak_time'],
#       dtype='object')
#
#
# Названия колонок в таблице ANTARES_NEW.csv со всеми кривыми блеска:
#
#  Index(['object_id', 'mjd', 'passband', 'flux', 'flux_err', 'obj_type',
#        'peak_time'],
#       dtype='object')
#
#
# Количество объектов:  1870
# Количество объектов:  1870
# Количество объектов:  1870
# Названия колонок в таблице ANTARES_NEW.csv со всеми кривыми блеска:
#
#  Index(['object_id', 'mjd', 'passband', 'flux', 'flux_err', 'obj_type',
#        'peak_time'],
#       dtype='object')
#
#
# Количество объектов:  1870
# Названия колонок в таблице ANTARES_NEW.csv со всеми кривыми блеска:
#
#  Index(['object_id', 'mjd', 'passband', 'flux', 'flux_err', 'obj_type',
#        'peak_time'],
#       dtype='object')
#
#
# Количество объектов:  1870
# Названия колонок в таблице ANTARES_NEW.csv со всеми кривыми блеска:
#
#  Index(['object_id', 'mjd', 'passband', 'flux', 'flux_err', 'obj_type',
#        'peak_time'],
#       dtype='object')
#
#
# Количество объектов:  1870
# Названия колонок в таблице ANTARES_NEW.csv со всеми кривыми блеска:
#
#  Index(['object_id', 'mjd', 'passband', 'flux', 'flux_err', 'obj_type',
#        'peak_time'],
#       dtype='object')
#
#
# Названия колонок в таблице ANTARES_NEW.csv со всеми кривыми блеска:
#
#  Количество объектов:  1870
# Index(['object_id', 'mjd', 'passband', 'flux', 'flux_err', 'obj_type',
#        'peak_time'],
#       dtype='object')
#
#
# Количество объектов:  1870
# Названия колонок в таблице ANTARES_NEW.csv со всеми кривыми блеска:
#
#  Index(['object_id', 'mjd', 'passband', 'flux', 'flux_err', 'obj_type',
#        'peak_time'],
#       dtype='object')
#
#
# Количество объектов:  1870
# Названия колонок в таблице ANTARES_NEW.csv со всеми кривыми блеска:
#
#  Index(['object_id', 'mjd', 'passband', 'flux', 'flux_err', 'obj_type',
#        'peak_time'],
#       dtype='object')
#
#
# Количество объектов:  1870
# Названия колонок в таблице ANTARES_NEW.csv со всеми кривыми блеска:
#
#  Index(['object_id', 'mjd', 'passband', 'flux', 'flux_err', 'obj_type',
#        'peak_time'],
#       dtype='object')
#
#
# Количество объектов:  1870
# got outputs
# (1870, 2, 256) (1870,)
# [   10] error: 0.340
# [   20] error: 0.309
# [   30] error: 0.290
# [   40] error: 0.264
# [   50] error: 0.250
# [   60] error: 0.241
# [   70] error: 0.223
# [   80] error: 0.217
# [   90] error: 0.207
# [  100] error: 0.199
# [  110] error: 0.176
# [  120] error: 0.175
# [  130] error: 0.160
# [  140] error: 0.142
# [  150] error: 0.161
# [  160] error: 0.140
# [  170] error: 0.124
# [  180] error: 0.133
# [  190] error: 0.133
# [  200] error: 0.121
# [  210] error: 0.102
# [  220] error: 0.104
# [  230] error: 0.123
# [  240] error: 0.113
# [  250] error: 0.113
# [  260] error: 0.081
# [  270] error: 0.087
# [  280] error: 0.079
# [  290] error: 0.092
# [  300] error: 0.083
# Finished Training
#        ROC_AUC    PR-AUC   LogLoss  Accuracy    Recall  Precision
# mean  0.957768  0.983812  0.258434  0.901176  0.912874   0.949988
# std   0.010117  0.004730  0.032339  0.015611  0.016912   0.013888
